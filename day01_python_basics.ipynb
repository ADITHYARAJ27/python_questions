# %% [markdown]
# <a href="https://colab.research.google.com/github/ADITHYARAJ27/python_questions/blob/main/day01_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mset={1,2,3}
print(mset)
# Out:
# {1, 2, 3}

# %%
mset.add(4)
print(mset)
# Out:
# {1, 2, 3, 4}

# %%
mset.update([4,5,6,7])
print(mset)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
mset.remove(2)
print(mset)
# Out:
# {1, 3, 4, 5, 6, 7}

# %%
#an element which is not in this will show an error

mset.remove(9)
print(mset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2694734355.py in <cell line: 0>()
#       1 #an element which is not in this will show an error
#       2
# ----> 3 mset.remove(9)
#       4 print(mset)
#
# KeyError: 9

# %%
#where in discard it will not show any error message

mset.discard(9)
print(mset)

# %%
mset.discard(6)
print(mset)

# %%
#pops a randon number from the list

poppeditem=mset.pop()
print(poppeditem)
print(mset)

# %%
#clears all the elemetns in set

mset.clear()
print(mset)

# %%
#union

set1={1,2,3,4}
set2={4,5,6,7}

unionset= set1 | set2
print(unionset)

# %%
#intersection

inte= set1 & set2
print(inte)

# %%
diff = set1 - set2
print(diff)

# %%
#symmetric difference

sd= set1 ^ set2
print(sd)

# %%
#subset and superset

#set1 = 1-100
#set2 = 20-60

#set1 is a superset of set2
#set2 is a subset of set1

# %%
set1 = {1,2,3,4,5}
set2 = {2,3}

print(set1.issubset(set2))
print(set1.issuperset(set2))
print(set2.issubset(set1))

# %%
#disjoint set -  sets which doesnt contain any common elements.

set1={1,2,3,4}
set2={5,6,7}

print(set1.isdisjoint(set2))
# Out:
# True

# %%
set1={1,2,3,4,5}
set2={5,6,7}

print(set1.isdisjoint(set2))
# Out:
# False

# %%
rows = 5

for i in range(1, rows + 1):
    # Print '*' i times
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# star patterns using nested if

# %%
n = 5

for i in range(1, n + 1):        # rows
    for j in range(1, n + 1):    # columns
        if j <= i:
            print("*", end="")
        else:
            print("", end="")
    print()   # move to next line
