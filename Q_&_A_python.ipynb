# %% [markdown]
# <a href="https://colab.research.google.com/github/ADITHYARAJ27/python_questions/blob/main/Q_%26_A_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Odd or Even:
#Write a program that takes an integer input from the user and checks whether it is odd or even.


num1=int(input("enter the number to be checked"))
if num1%2==0:
  print("the number is even")
else:
  print("the number is odd")
# Out:
# enter the number to be checked10
# the number is even

# %%
#Age Eligibility:
#Write a program to check if a user is eligible to vote. If the user's age is 18 or above, print "Eligible to vote"; otherwise, print "Not eligible to vote."


age=int(input("enter your age"))
if age>18:
  print("eligible to vote")
elif age==18:
  print("eligible, this is your first vote")
else:
  print("not eligible to vote")
# Out:
# enter your age18
# eligible, this is your first vote

# %%
  """
  Grading System:
Write a program that accepts a student's score (0-100) and prints the grade based on the score:

90-100: "A"
80-89: "B"
70-79: "C"
60-69: "D"
Below 60: "F"
"""

marks=int(input("enter the mark"))
if marks>=90 and marks<=100:
    print("A grade")
elif marks>=80 and marks<90:
    print("B grade")
elif marks>=70 and marks<80:
    print("C grade")
elif marks>=60 and marks<70:
    printZ("D grade")
elif marks<60:
    print("F")
else:
    print("enter the correct mark")
# Out:
# enter the mark90
# A grade

# %%
"""Leap Year Checker:
Write a program that takes a year as input and checks if it is a leap year. A year is a leap year if it is divisible by 4 but not by 100, or if it is divisible by 400."""


leap_year=int(input("enter the year"))
if leap_year!=100 and leap_year!=400:
    if leap_year%4==0:
        print("leap year")
    else:
        print("not a leap year")
# Out:
# enter the year2020
# leap year

# %%
"""Temperature Conversion:
Ask the user to input a temperature in Fahrenheit and convert it to Celsius. If the Celsius temperature is below 0, print "Freezing cold"; between 0 and 20, print "Cold";
 between 20 and 30, print "Warm"; and above 30, print "Hot"."""

fahrenheit=float(input("enter the temperature"))
celsius = (fahrenheit - 32) * 5 / 9
print(celsius)
if celsius<=0:
  print("freezing cold")
elif celsius>0 and celsius<=20:
  print("cold")
elif celsius>20 and celsius<=30:
  print("warm")
elif celsius>30:
  print("hot")
# Out:
# enter the temperature30
# -1.1111111111111112
# freezing cold

# %%
"""Login Authentication:
Create a simple login program that asks the user for a username and password. If both are correct (e.g., username is "admin" and password is "1234"),
 print "Login successful"; otherwise, print "Login failed."""


username=str(input("enter the username"))
password=int(input("enter the password"))

if username=="adi" and password==123:
  print("logged in")
else:
    print("failed")
# Out:
# enter the usernameadi
# enter the password123
# logged in

# %%
"""Triangle Type Checker:
Take three side lengths from the user and determine if they form an equilateral, isosceles, or scalene triangle,
 or if they cannot form a triangle at all (if any two sides sum to less than or equal to the third side)."""
# Out:
# 'Triangle Type Checker:\nTake three side lengths from the user and determine if they form an equilateral, isosceles, or scalene triangle,\n or if they cannot form a triangle at all (if any two sides sum to less than or equal to the third side).'

# %%
"""Number Comparison:
Write a program that takes three numbers as input and determines the largest of the three."""


num1=int(input("A = "))
num2=int(input("B = "))
num3=int(input("c = "))

if num1>num2 and num1>num3:
  print("A is greater")
elif num2>num1 and num2>num3:
  print("B is greater")
else:
  print("C is greater")
# Out:
# A = 10
# B = 30
# c = 20
# B is greater

# %%
"""Simple Calculator:
Write a program that asks the user to input two numbers and an operator (+, -, *, /). Use if-else conditions to perform the appropriate operation and display the result.
 If the operator is invalid, display an error message."""
# Out:
# 3

# %% [markdown]
# interview questions

# %% [markdown]
# 1. Reversing Words in a Sentence
#
# Question: Write a program to take a sentence as input and print the sentence with the order of words reversed. For example:
#
# Input: "Python programming is fun"
#
# Output: "fun is programming Python"
#
#
# Hint: Use a suitable data structure to temporarily store the words and use a loop to process them.

# %%
text1="python programming is fun"
a=text1.split()
print(a)
a.reverse()
print(a)
# Out:
# ['python', 'programming', 'is', 'fun']
# ['fun', 'is', 'programming', 'python']

# %% [markdown]
#   2. Frequency Counter
#
# Question: Write a program to count the frequency of each character in a given string. Ignore spaces and consider both uppercase and lowercase letters as the same.
#
# Input: "Hello World"
#
# Output:
#
# h: 1
# e: 1
# l: 3
# o: 2
# w: 1
# r: 1
# d: 1
#
# Hint: Use a dictionary to store the frequency of each character. Iterate through the string and check if the character is already in the dictionary.

# %%
# text = "Hello World"
# freq = {}

# for char in text.lower():   # step 1: lowercase
#     if char != " ":         # step 2: ignore space
#         if char in freq:
#             freq[char] += 1
#         else:
#             freq[char] = 1

# for k, v in freq.items():
#     print(f"{k}: {v}", end=" ")   #end=" " ->this is to print it in the same line


text="Hello World"
freq={}

for i in text:
  if i != " ":
    if i not in freq:
      freq[i]=1
    else:
      freq[i]+=1

for i in freq:
  print(f"{i}: {freq[i]}")
# Out:
# H: 1
# e: 1
# l: 3
# o: 2
# W: 1
# r: 1
# d: 1

# %% [markdown]
# 3. Number Pattern Generator
#
# Question: Write a program to generate the following number pattern for a given n (input by the user):
#
# Input: n = 5
#
# Output:
#
# 1
# 12
# 123
# 1234
# 12345
#
#
# Hint: Use nested loops to generate the numbers for each row.

# %%
n = 5
h=0
for i in range(1, n + 1):        # rows
    for j in range(1, i + 1):    # numbers
        print(j, end="")

    print()   # move to next line
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %% [markdown]
# 4. Set Operations
#
# Question: Write a program to take two lists of integers as input from the user. Convert them into sets and perform the following operations:
#
# 1. Find the union of the two sets.
#
#
# 2. Find the intersection of the two sets.
#
#
# 3. Find the difference of the first set from the second.
#
# Input:
#
# List 1: [1, 2, 3, 4, 5]
# List 2: [4, 5, 6, 7, 8]
#
# Output:
#
# Union: {1, 2, 3, 4, 5, 6, 7, 8}
# Intersection: {4, 5}
# Difference: {1, 2, 3}
#
#
# Hint: Use set operations like .union(), .intersection(), and .difference().

# %%
num1=list(input("enter the numbers"))
num2=list(input("enter the numbers"))

s1=set(num1)
s2=set(num2)
print(s1 | s2)
print(s1 & s2)
print(s1 - s2)

# %% [markdown]
# 5. Student Score Analysis
#
# Question: Write a program to take the names and marks of students as input. Store them in a dictionary and perform the following tasks:
#
# 1. Print the name of the student with the highest marks.
#
#
# 2. Print the average marks of the class.
#
#
#
# Input:
#
# Number of students: 3
# Name: Alice, Marks: 85
# Name: Bob, Marks: 90
# Name: Charlie, Marks: 78
#
# Output:
#
# Topper: Bob
# Average Marks: 84.33
#
#
# Hint: Use a dictionary to store names and marks. Use loops to calculate the maximum marks and the average.

# %%
students = {}

n = int(input("Number of students: "))

for i in range(n):
    name = input("Name: ")
    marks = int(input("Marks: "))
    students[name] = marks

# Find topper
topper = max(students, key=students.get)

# Calculate average
total = sum(students.values())
average = total / n

print("Topper:", topper)
print("Average Marks:", round(average, 2))

# %% [markdown]
# part 2

# %% [markdown]
# Write a function to find the cube of a number.

# %%
def cub(n):
  return n*n*n

cub(2)
# Out:
# 8

# %% [markdown]
# 2. Write a function to check if a number is positive, negative, or zero.

# %%
def dig(n):
  if n>0:
    print("positive")
  elif n<0:
    print("negetive")
  else:
    print("zero")

dig(2)
dig(-3)
dig(0)
# Out:
# positive
# negetive
# zero

# %% [markdown]
# 3.Write a function to calculate the perimeter of a rectangle given its length and width

# %% [markdown]
# 4. Write a function to multiply all numbers in a list.

# %%
def mul(num):
  res=1
  for i in num:
    res*=i

  return res

print(mul([1,2,3]))
# Out:
# 6

# %%
#using normal method
n=[1,2,3]
z=1
for i in n:
  z*=i
print(z)
# Out:
# 6

# %% [markdown]
# 5. Write a function to greet a user with a customizable message.

# %%
def greet(name):
  print(name)

greet(str(input("enter the message: ")))
# Out:
# enter the message: hi helo
# hi helo

# %% [markdown]
# 6. Write a function to calculate the power of a number using recursion.

# %%
def poower(b,e:)

# %% [markdown]
# 7. Write a function to count the consonants in a given string.

# %%
def con(name):
  count=0
  vowels="aeiou"
  for i in name:
    if i not in vowels:
      count+=1

  print(count)
con("hell")
# Out:
# 3

# %% [markdown]
# 8. Write a function to check if two strings are anagrams of each other.

# %% [markdown]
# 9. Write a function to find the minimum number in a list.

# %%
def minimum(num):
  return min(num)

minimum(list(input("enter the numbers: ")))
# Out:
# enter the numbers: 30394
# '0'

# %% [markdown]
# 10. Write a function to calculate the nth triangular number using recursion.

# %% [markdown]
# 11. Write a function to replace all spaces in a string with a specified character.

# %%
def rep(x):
  for i in x:
    if i == " ":
      print( "*")

rep(str(input("enter the word: ")))
# Out:
# enter the word: h eh e
# *
# *
